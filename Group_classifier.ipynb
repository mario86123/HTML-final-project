# %%
import numpy as np
import pandas as pd
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x_test = pd.read_csv('/content/drive/MyDrive/HTML final project/x_test.csv',index_col=0)
x_test = x_test.fillna(x_test.median())
x_test = x_test.to_numpy()

# %%
# read group training data 
# data X
group_train_data_x =[]
group_train_data_y =[]
for i in range(1,8):
  group_train_data = pd.read_csv('/content/drive/MyDrive/HTML final project/train_group'+str(i)+'.csv',index_col=0)
  print(group_train_data.columns) 
  group_train_data_x.append(group_train_data.iloc[:, :-1])
  group_train_data_x[i-1]["Satisfaction Score"] =   group_train_data_x[i-1]["Satisfaction Score"].fillna(group_train_data_x[i-1]['Satisfaction Score'].median())
  #group_train_data_x[i-1] = group_train_data_x[i-1].fillna(group_train_data_x[i-1].median())
  group_train_data_x[i-1] = group_train_data_x[i-1].to_numpy()

  group_train_data_y.append( group_train_data['Churn Category'])
  group_train_data_y[i-1] = group_train_data_y[i-1].fillna(group_train_data_y[i-1].median())
  group_train_data_y[i-1] = group_train_data_y[i-1].to_numpy()

  

  print("group",i,"x_train.shape:" , group_train_data_x[i-1].shape )
  print("group",i,"y_train.shape: ", group_train_data_y[i-1].shape)

"""
group_train_data = pd.read_csv('/content/drive/MyDrive/HTML final project/all_impute_data.csv',index_col=0)
#print(group_train_data.columns) 
group_train_data_x.append(group_train_data.iloc[:, :-1])
group_train_data_x[i-1]["Satisfaction Score"] =   group_train_data_x[i-1]["Satisfaction Score"].fillna(group_train_data_x[i-1]['Satisfaction Score'].median())
#group_train_data_x[i-1] = group_train_data_x[i-1].fillna(group_train_data_x[i-1].median())
group_train_data_x[i-1] = group_train_data_x[i-1].to_numpy()

group_train_data_y.append( group_train_data['Churn Category'])
group_train_data_y[i-1] = group_train_data_y[i-1].fillna(group_train_data_y[i-1].median())
group_train_data_y[i-1] = group_train_data_y[i-1].to_numpy()
"""
# Out:
# Index(['Multiple Lines', 'Monthly Charge', 'Online Security', 'Phone Service',
#        'Contract', 'Internet Type', 'Avg Monthly Long Distance Charges',
#        'Total Refunds', 'Paperless Billing', 'Unlimited Data',
#        'Premium Tech Support', 'Referred a Friend', 'Streaming TV',
#        'Avg Monthly GB Download', 'Device Protection Plan',
#        'Total Long Distance Charges', 'Tenure in Months', 'Internet Service',
#        'Total Charges', 'Payment Method', 'Online Backup', 'Offer',
#        'Streaming Movies', 'Total Revenue', 'Streaming Music',
#        'Total Extra Data Charges', 'Number of Referrals', 'Satisfaction Score',
#        'Churn Category'],
#       dtype='object')
# group 1 x_train.shape: (3238, 28)
# group 1 y_train.shape:  (3238,)
# Index(['Latitude', 'Longitude', 'Population', 'City', 'Zip Code',
#        'Satisfaction Score', 'Churn Category'],
#       dtype='object')
# group 2 x_train.shape: (3240, 6)
# group 2 y_train.shape:  (3240,)
# ...

# %%
all = pd.read_csv('/content/drive/MyDrive/HTML final project/all_impute_data.csv',index_col=0)
all_with = all.drop(columns=['Count'])
all_without = all.drop(columns=['Customer ID','Count'])
all_x = all_with.iloc[:, :-1]
all_y = all_with.iloc[:, -1]

# %%
all_without
# Out:
#         Gender   Age  ...  Satisfaction Score  Churn Category
# 0     1.000000  78.0  ...                 NaN               1
# 1     0.000000  74.0  ...                 3.0               1
# 2     1.000000  71.0  ...                 NaN               1
# 3     0.000000  78.0  ...                 2.0               2
# 4     0.571429  80.0  ...                 2.0               4
# ...        ...   ...  ...                 ...             ...
# 4221       NaN   NaN  ...                 5.0               0
# 4222       NaN   NaN  ...                 3.0               0
# 4223       NaN   NaN  ...                 4.0               0
# 4224       NaN   NaN  ...                 5.0               0
# 4225       NaN   NaN  ...                 4.0               0
#
# [4226 rows x 45 columns]

# %%
from sklearn.model_selection import train_test_split


x_val_train, x_val_test, y_val_train, y_val_test = train_test_split(all_x, all_y , test_size=0.2)

# %%
x_val_train['Satisfaction Score'] =  x_val_train['Satisfaction Score'].fillna(x_val_train['Satisfaction Score'].median())
x_val_test['Satisfaction Score']  =  x_val_test['Satisfaction Score'].fillna(x_val_train['Satisfaction Score'].median())

# %%
x_val_train
# Out:
#      Customer ID  Gender  ...  Total Revenue  Satisfaction Score
# 2816  5845-BZZIB     1.0  ...        1978.20                 3.0
# 818   4009-ALQFH     1.0  ...         592.15                 2.0
# 1934  7594-RQHXR     1.0  ...        6575.85                 3.0
# 875   3703-TTEPD     1.0  ...        1055.40                 3.0
# 503   6967-PEJLL     1.0  ...       10016.95                 5.0
# ...          ...     ...  ...            ...                 ...
# 1225  7691-KGKGP     0.0  ...            NaN                 1.0
# 3803  1400-MMYXY     NaN  ...        2287.60                 3.0
# 2405  7271-AJDTL     0.0  ...         874.37                 3.0
# 3723  0013-SMEOE     NaN  ...        4126.30                 4.0
# 24    4342-HFXWS     0.0  ...        4983.82                 1.0
#
# [3380 rows x 45 columns]

# %%
# !pip install catboost
# from catboost import CatBoostClassifier
from xgboost.sklearn import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.ensemble import StackingClassifier
# CAT = CatBoostClassifier
MLP = MLPClassifier()
NB = GaussianNB()
QDA = QuadraticDiscriminantAnalysis()
SVCCC = SVC()
LR = LogisticRegression()
KNN = KNeighborsClassifier()
SGD = SGDClassifier()
ADA = AdaBoostClassifier()
DT = DecisionTreeClassifier()
RF = BaggingClassifier(DT)
XGB = XGBClassifier()
LGBM = LGBMClassifier()
GDB = GradientBoostingClassifier()


VOTE = VotingClassifier(
estimators=[('xgb', XGB) ,('lgbm', LGBM), ('gdb', GDB)],
 voting='soft')

STACK =  clf = StackingClassifier(
    estimators=[('lgbm', LGBM), ('gdb', GDB)], final_estimator=LogisticRegression()
 )
# train
# ================
clf_lst = [MLP, NB, QDA, SVCCC, LR, KNN, SGD, ADA, DT, RF, XGB, LGBM, GDB ,VOTE]
# clf_lst = [ADA, DT, XGB, LGBM, GDB]
val_acc_lst = []

group_CLFs = []

for i in range(7):
    GDB = GradientBoostingClassifier()
    
    group_CLFs.append(GDB.fit(group_train_data_x[i], group_train_data_y[i]))
    
    #val_acc = metrics.f1_score(y_val_test, val_y_predicted , average="macro")
    #val_acc_lst.append(val_acc)



"""
print()
print("f1_score:")
for i in range(len(clf_lst)):
  print(clf_lst[i])
  print(val_acc_lst[i])
"""
# Out:
# '\nprint()\nprint("f1_score:")\nfor i in range(len(clf_lst)):\n  print(clf_lst[i])\n  print(val_acc_lst[i])\n'

# %%
all
# Out:
#      Customer ID  Count  ...  Satisfaction Score  Churn Category
# 0     1746-TGTWV    1.0  ...                 NaN               1
# 1     8499-BRXTD    1.0  ...                 3.0               1
# 2     2041-JIJCI    1.0  ...                 NaN               1
# 3     5832-EXGTT    1.0  ...                 2.0               2
# 4     8350-NYMVI    1.0  ...                 2.0               4
# ...          ...    ...  ...                 ...             ...
# 4221  7817-BOQPW    NaN  ...                 5.0               0
# 4222  4767-HZZHQ    NaN  ...                 3.0               0
# 4223  6981-TDRFT    NaN  ...                 4.0               0
# 4224  3094-JOJAI    NaN  ...                 5.0               0
# 4225  9079-YEXQJ    NaN  ...                 4.0               0
#
# [4226 rows x 47 columns]

# %%
y_pred_train=[]
count = 0
for id in all["Customer ID"]:
  y_pred_train.append([])
  row = all.loc[all['Customer ID'] == id]
  
  for i in range(7):
    #print(i)
    group_row = row[group_Cols[i]]
    
    if(group_row.isnull().values.any()):

      y_pred_train[count].append(-1)
    else:
      #print
      y_pred_train[count].append(group_CLFs[i].predict(group_row)[0])

  count += 1
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# ...

# %%
count
# Out:
# 4226

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
final=make_pipeline(StandardScaler(), SVC(gamma='auto'))
final.fit(y_pred_train , all_y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %%
gropu1

# %%
group_Cols = {
0 : ['Internet Type', 'Total Charges', 'Online Backup', 'Paperless Billing', 'Avg Monthly GB Download', 'Contract', 'Streaming TV', 'Monthly Charge', 'Device Protection Plan', 'Referred a Friend', 'Avg Monthly Long Distance Charges', 'Total Long Distance Charges', 'Tenure in Months', 'Internet Service', 'Total Revenue', 'Online Security', 'Total Refunds', 'Multiple Lines', 'Streaming Movies', 'Number of Referrals', 'Total Extra Data Charges', 'Unlimited Data', 'Payment Method', 'Offer', 'Streaming Music', 'Phone Service', 'Premium Tech Support', 'Satisfaction Score'],
1 : ['Population', 'City', 'Latitude', 'Longitude', 'Zip Code', 'Satisfaction Score'],
2 : ['Internet Type', 'Total Charges', 'Online Backup', 'Paperless Billing', 'City', 'Avg Monthly GB Download', 'Contract', 'Longitude', 'Streaming TV', 'Zip Code', 'Latitude', 'Monthly Charge', 'Device Protection Plan', 'Referred a Friend', 'Avg Monthly Long Distance Charges', 'Total Long Distance Charges', 'Population', 'Tenure in Months', 'Internet Service', 'Total Revenue', 'Online Security', 'Total Refunds', 'Multiple Lines', 'Number of Referrals', 'Streaming Movies', 'Total Extra Data Charges', 'Unlimited Data', 'Payment Method', 'Offer', 'Streaming Music', 'Phone Service', 'Premium Tech Support', 'Satisfaction Score'],
3 : ['Number of Dependents', 'Senior Citizen', 'Under 30', 'Age', 'Gender', 'Married', 'Dependents', 'Satisfaction Score'],
4 : ['Internet Type', 'Total Charges', 'Online Backup', 'Paperless Billing', 'Gender', 'Avg Monthly GB Download', 'Contract', 'Streaming TV', 'Monthly Charge', 'Device Protection Plan', 'Senior Citizen', 'Referred a Friend', 'Age', 'Avg Monthly Long Distance Charges', 'Total Long Distance Charges', 'Tenure in Months', 'Internet Service', 'Total Revenue', 'Online Security', 'Total Refunds', 'Multiple Lines', 'Number of Referrals', 'Streaming Movies', 'Number of Dependents', 'Unlimited Data', 'Payment Method', 'Total Extra Data Charges', 'Offer', 'Under 30', 'Streaming Music', 'Married', 'Phone Service', 'Premium Tech Support', 'Dependents', 'Satisfaction Score'],
5 : ['Number of Dependents', 'Population', 'Senior Citizen', 'Under 30', 'Age', 'City', 'Gender', 'Latitude',  'Married', 'Dependents', 'Longitude', 'Zip Code', 'Satisfaction Score'],
6 : ['Internet Type', 'Total Charges', 'Online Backup', 'Paperless Billing', 'City', 'Gender', 'Avg Monthly GB Download', 'Contract', 'Longitude', 'Streaming TV', 'Zip Code', 'Latitude', 'Monthly Charge', 'Device Protection Plan', 'Senior Citizen', 'Referred a Friend', 'Age', 'Avg Monthly Long Distance Charges', 'Total Long Distance Charges', 'Population', 'Tenure in Months', 'Internet Service', 'Phone Service', 'Total Revenue', 'Online Security', 'Total Refunds', 'Multiple Lines', 'Number of Referrals', 'Streaming Movies', 'Number of Dependents', 'Unlimited Data', 'Payment Method', 'Total Extra Data Charges', 'Offer', 'Under 30', 'Streaming Music', 'Married', 'Dependents', 'Premium Tech Support', 'Satisfaction Score']
}

# %%
all_test = pd.read_csv('/content/drive/MyDrive/HTML final project/all_impute_test.csv',index_col=0)
all_test['Satisfaction Score'] = all_test['Satisfaction Score'].fillna(all_test['Satisfaction Score'].median())
y_pred = []
count = 0
for id in all_test["Customer ID"]:
  y_pred.append([])
  row = all_test.loc[all_test['Customer ID'] == id]
  
  for i in range(7):
    #print(i)
    group_row = row[group_Cols[i]]
    
    if(group_row.isnull().values.any()):
      y_pred[count].append(-1)
    else:
      #print
      y_pred[count].append(group_CLFs[i].predict(group_row)[0])
  count += 1
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# ...

# %%
"""
from collections import Counter

test_y_predicted = []
for i in y_pred:
  test_y_predicted = 
  c = [y_pred[i][j] for j in range(len(y_pred[i]))]


  counts = np.bincount(c)
  if len(counts) == 0 :
    test_y_predicted.append(-1)
  else:
    test_y_predicted.append(np.argmax(counts))
"""
test_y_predicted = final.predict(y_pred)

# %%
Test_IDs = pd.read_csv('/content/drive/MyDrive/HTML final project/Test_IDs.csv')
Test_IDs["Churn Category"] = test_y_predicted
Test_IDs.to_csv('Grouplast_chance_2.csv', index=False)
