# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read CSV
services = pd.read_csv('/content/drive/MyDrive/HTML final project/services.csv')

services.fillna(value = {"Count": 1.0, "Quarter": 'Q3'}, inplace = True)
services['Quarter'].replace(['Q3'], [0.0], inplace = True)
services['Referred a Friend'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Phone Service'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Multiple Lines'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Internet Service'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Online Security'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Online Backup'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Device Protection Plan'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Premium Tech Support'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Streaming TV'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Streaming Movies'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Streaming Music'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Unlimited Data'].replace(['No', 'Yes'], [0, 1], inplace = True)
services['Paperless Billing'].replace(['No', 'Yes'], [0, 1], inplace = True)

# offer (None, A, B, C, D, E) to (0, 1, 2, 3, 4, 5)
services['Offer'].replace(sorted(services['Offer'].loc[~services['Offer'].isnull()].unique()),
                          list(range(len(services['Offer'].loc[~services['Offer'].isnull()].unique()))), inplace = True)
# ['Cable', 'DSL', 'Fiber Optic', 'None'] to [0, 1, 2, 3]
services['Internet Type'].replace(sorted(services['Internet Type'].loc[~services['Internet Type'].isnull()].unique()),
                         list(range(len(services['Internet Type'].loc[~services['Internet Type'].isnull()].unique()))), inplace = True)
# ['Month-to-Month', 'One Year', 'Two Year'] to [0, 1, 2]
services['Contract'].replace(sorted(services['Contract'].loc[~services['Contract'].isnull()].unique()),
                         list(range(len(services['Contract'].loc[~services['Contract'].isnull()].unique()))), inplace = True)
# ['Bank Withdrawal', 'Credit Card', 'Mailed Check'] to [0, 1, 2]
services['Payment Method'].replace(sorted(services['Payment Method'].loc[~services['Payment Method'].isnull()].unique()),
                         list(range(len(services['Payment Method'].loc[~services['Payment Method'].isnull()].unique()))), inplace = True)

services
# Out:
#      Customer ID  Count  ...  Total Long Distance Charges  Total Revenue
# 0     1746-TGTWV    1.0  ...                         0.00          59.65
# 1     8499-BRXTD    1.0  ...                       390.80        1024.10
# 2     5832-EXGTT    1.0  ...                       494.00        2995.07
# 3     8350-NYMVI    1.0  ...                       234.21        3102.36
# 4     7284-BUYEC    1.0  ...                        89.91        2235.41
# ...          ...    ...  ...                          ...            ...
# 6158  7609-NRNCA    1.0  ...                      1639.44        3039.53
# 6159  4835-YSJMR    1.0  ...                       865.20        2807.47
# 6160  5067-DGXLL    1.0  ...                      2135.52        9453.04
# 6161  3129-AAQOU    1.0  ...                         0.00         319.21
# 6162  2205-LPVGL    1.0  ...                      2043.36        8887.86
#
# [6163 rows x 30 columns]

# %%
print(services[['Referred a Friend', 'Number of Referrals']].isna().sum())
services.loc[services['Number of Referrals'] > 0, ['Referred a Friend']] = 1
services.loc[services['Number of Referrals'] == 0, ['Referred a Friend']] = 0
services.loc[services['Referred a Friend'] == 0, ['Number of Referrals']] = 0
print(services[['Referred a Friend', 'Number of Referrals']].isna().sum())
services[(services['Referred a Friend'] == 1) & (services['Number of Referrals'].isnull())]
# Out:
# Referred a Friend      770
# Number of Referrals    770
# dtype: int64
# Referred a Friend      101
# Number of Referrals    428
# dtype: int64
#      Customer ID  Count  ...  Total Long Distance Charges  Total Revenue
# 52    3115-CZMZD    1.0  ...                       440.82        6824.17
# 84    0196-JTUQI    1.0  ...                        83.64        1033.84
# 87    0014-BMAQU    1.0  ...                        19.11        1188.46
# 123   7609-YBPXG    1.0  ...                      1904.76        8726.91
# 134   5419-KLXBN    1.0  ...                      2259.06        6753.62
# ...          ...    ...  ...                          ...            ...
# 6102  6689-TCZHQ    1.0  ...                          NaN       10184.55
# 6113  5639-NTUPK    1.0  ...                       235.30            NaN
# 6120  2908-ZTPNF    1.0  ...                         0.00        2780.60
# 6134  9405-GPBBG    1.0  ...                      1487.88        4837.37
# 6141  4137-JOPHL    1.0  ...                      3152.64        9915.15
#
# [327 rows x 30 columns]

# %% [markdown]
# # fill in nan by median

# %%
num_referrals_median = services[(services['Referred a Friend'] == 1) & services['Number of Referrals'].notnull()]['Number of Referrals'].median()
print(num_referrals_median)
services.loc[services['Number of Referrals'].isna() & (services['Referred a Friend'] == 1), 'Number of Referrals'] = num_referrals_median
print(services[['Referred a Friend', 'Number of Referrals']].isna().sum())
# Out:
# 4.0
# Referred a Friend      101
# Number of Referrals    101
# dtype: int64

# %%
services[services['Referred a Friend'].isna()]
# Out:
#      Customer ID  Count  ...  Total Long Distance Charges  Total Revenue
# 102   1544-JJMYL    1.0  ...                       559.30        4212.65
# 132   6519-ZHPXP    1.0  ...                       352.95        1443.54
# 261   0402-CQAJN    1.0  ...                          NaN          73.11
# 301   7779-LGOVN    1.0  ...                       242.56        1830.11
# 369   2067-QYTCF    1.0  ...                      2063.40        8614.80
# ...          ...    ...  ...                          ...            ...
# 5855  1216-BGTSP    1.0  ...                          NaN         327.30
# 5932  4139-JPIAM    1.0  ...                       255.43            NaN
# 5950  1087-UDSIH    1.0  ...                      2429.42        3330.32
# 5951  8985-OOPOS    1.0  ...                       978.48            NaN
# 6072  1035-IPQPU    1.0  ...                         0.00        1051.05
#
# [101 rows x 30 columns]

# %%
services.to_csv('/content/drive/MyDrive/HTML final project/new_services.csv', index=False)
